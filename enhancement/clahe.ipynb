# %%
import cv2
import os
import numpy as np

# Input folders: use the contrast-stretched frames as input
input_folders = {
    "median": "denoised_median"
}

# Output folders: CLAHE enhanced frames
output_folders = {
    "median": "enhanced_median_clahe"
}

# Create output folders if they don't exist
for folder in output_folders.values():
    os.makedirs(folder, exist_ok=True)

# Function: Apply optimized CLAHE
def apply_optimized_clahe(img, clip_limit=2.0, tile_grid_size=(16,16), blend_alpha=0.8):
   
    clahe = cv2.createCLAHE(clipLimit=clip_limit, tileGridSize=tile_grid_size)
    clahe_img = clahe.apply(img)

    # Optional smoothing to reduce roughness
    clahe_img = cv2.GaussianBlur(clahe_img, (3,3), 0)

    # Blend with original to preserve natural look
    final_img = cv2.addWeighted(clahe_img, blend_alpha, img, 1 - blend_alpha, 0)
    return final_img

# Process frames
for method, folder in input_folders.items():
    print(f"\nApplying Optimized CLAHE on {method.upper()} frames...")
    for filename in sorted(os.listdir(folder)):
        if not filename.endswith(".png"):
            continue

        img_path = os.path.join(folder, filename)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        if img is None:
            continue

        enhanced_img = apply_optimized_clahe(img, clip_limit=2.0, tile_grid_size=(16,16), blend_alpha=0.8)

        # Save output
        save_path = os.path.join(output_folders[method], filename)
        cv2.imwrite(save_path, enhanced_img)

        # Print contrast for report
        orig_contrast = np.std(img)
        new_contrast = np.std(enhanced_img)
        print(f"{filename}: Original Contrast={orig_contrast:.2f}, CLAHE Contrast={new_contrast:.2f}")

print("\nOptimized CLAHE Completed! Enhanced frames saved successfully.")
# Out:
# Applying Optimized CLAHE on MEDIAN frames...
# frame_0.png: Original Contrast=19.97, CLAHE Contrast=22.53
# frame_1.png: Original Contrast=18.38, CLAHE Contrast=21.34
# frame_10.png: Original Contrast=19.09, CLAHE Contrast=23.23
# frame_11.png: Original Contrast=18.24, CLAHE Contrast=22.01
# frame_12.png: Original Contrast=21.38, CLAHE Contrast=24.94
# frame_13.png: Original Contrast=20.61, CLAHE Contrast=24.17
# frame_14.png: Original Contrast=21.87, CLAHE Contrast=24.67
# frame_15.png: Original Contrast=21.78, CLAHE Contrast=24.16
# frame_16.png: Original Contrast=16.07, CLAHE Contrast=20.02
# frame_17.png: Original Contrast=14.49, CLAHE Contrast=18.19
# frame_18.png: Original Contrast=15.85, CLAHE Contrast=19.22
# frame_19.png: Original Contrast=15.92, CLAHE Contrast=19.51
# frame_2.png: Original Contrast=19.13, CLAHE Contrast=22.59
# frame_20.png: Original Contrast=15.07, CLAHE Contrast=18.49
# frame_21.png: Original Contrast=14.53, CLAHE Contrast=18.22
# frame_22.png: Original Contrast=15.46, CLAHE Contrast=19.12
# frame_23.png: Original Contrast=15.57, CLAHE Contrast=19.50
# frame_24.png: Original Contrast=14.99, CLAHE Contrast=18.63
# frame_25.png: Original Contrast=14.06, CLAHE Contrast=18.00
# frame_26.png: Original Contrast=13.98, CLAHE Contrast=18.03
# frame_27.png: Original Contrast=13.37, CLAHE Contrast=17.51
# frame_28.png: Original Contrast=15.21, CLAHE Contrast=19.36
# frame_29.png: Original Contrast=16.44, CLAHE Contrast=20.72
# frame_3.png: Original Contrast=18.09, CLAHE Contrast=21.72
# frame_30.png: Original Contrast=18.25, CLAHE Contrast=22.42
# frame_31.png: Original Contrast=21.13, CLAHE Contrast=24.59
# frame_32.png: Original Contrast=22.72, CLAHE Contrast=26.22
# frame_33.png: Original Contrast=21.92, CLAHE Contrast=25.51
# frame_34.png: Original Contrast=21.20, CLAHE Contrast=25.16
# frame_35.png: Original Contrast=22.32, CLAHE Contrast=26.17
# frame_4.png: Original Contrast=21.33, CLAHE Contrast=24.40
# frame_5.png: Original Contrast=22.22, CLAHE Contrast=25.14
# frame_6.png: Original Contrast=25.71, CLAHE Contrast=28.59
# frame_7.png: Original Contrast=22.40, CLAHE Contrast=25.53
# frame_8.png: Original Contrast=20.55, CLAHE Contrast=24.04
# frame_9.png: Original Contrast=20.31, CLAHE Contrast=24.19
#
# Optimized CLAHE Completed! Enhanced frames saved successfully.
